# %% [markdown]
# # Libraries

# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import re
from nltk.stem import WordNetLemmatizer
from tqdm import tqdm
import time
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import seaborn as sns

# %% [markdown]
# # Loading the data

# %%
DATASET_COLUMNS  = ["sentiment", "ids", "date", "flag", "user", "text"]
DATASET_ENCODING = "ISO-8859-1"
dataset = pd.read_csv('C:/Users/IDEH/Desktop/Sentimental/Data/Sentiment140.csv',
                      encoding=DATASET_ENCODING , names=DATASET_COLUMNS)
dataset
# Out:
#          sentiment         ids                          date      flag  \
# 0                0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1                0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2                0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3                0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4                0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...            ...         ...                           ...       ...
# 1599995          4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996          4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997          4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998          4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999          4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# ...

# %% [markdown]
# Data Preprocessing

# %%
dataset = dataset[['sentiment','text']]
sentiment_counts = dataset['sentiment'].value_counts()
print(sentiment_counts)
# Out:
# 0    800000
# 4    800000
# Name: sentiment, dtype: int64

# %%
# Map sentiment labels to integers (0: negative, 4: positive)
sentiment_map = {0: 0, 4: 1}  # 0: negative, 1: positive
dataset.loc[:, 'sentiment'] = dataset['sentiment'].map(sentiment_map)
# Out:
# C:\Users\IDEH\AppData\Local\Temp\ipykernel_16868\2550957762.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.loc[:, 'sentiment'] = dataset['sentiment'].map(sentiment_map)

# %%
# sentiment_counts = dataset['sentiment'].value_counts()
# print(sentiment_counts)
# import matplotlib.pyplot as plt

# # Assuming sentiment_counts is a pandas Series
# sentiment_counts = dataset['sentiment'].value_counts()

# # Plotting the bar chart
# plt.figure(figsize=(10, 6))
# sentiment_counts.plot(kind='bar', color='skyblue')
# plt.title('Sentiment Distribution')
# plt.xlabel('Sentiment')
# plt.ylabel('Counts')
# plt.xticks(rotation=0)
# plt.show()

# %% [markdown]
# # Preprocessing

# %%
import re
from nltk.stem import WordNetLemmatizer
from tqdm import tqdm
import time

# Define your custom preprocessing function with tqdm and time
def preprocess(textdata):
    processedText = []
    wordLemm = WordNetLemmatizer()
    urlPattern = r"((http://)[^ ]*|(https://)[^ ]*|( www\.)[^ ]*)"
    userPattern = '@[^\s]+'
    alphaPattern = "[^a-zA-Z0-9]"
    sequencePattern = r"(.)\1\1+"
    seqReplacePattern = r"\1\1"
    
    start_time = time.time()
    
    for tweet in tqdm(textdata, desc="Processing tweets", unit="tweet"):
        tweet = tweet.lower()
        tweet = re.sub(urlPattern, ' URL', tweet)
        tweet = re.sub(userPattern, ' USER', tweet)
        tweet = re.sub(alphaPattern, " ", tweet)
        tweet = re.sub(sequencePattern, seqReplacePattern, tweet)
        tweetwords = ''
        for word in tweet.split():
            word = wordLemm.lemmatize(word)
            tweetwords += (word + ' ')
        processedText.append(tweetwords)
    
    end_time = time.time()
    print(f"Preprocessing completed in {end_time - start_time:.2f} seconds")
    
    return processedText

# Apply the preprocessing function to the text data
processed_text = preprocess(dataset['text'].values)
# Out:
# Processing tweets: 100%|████████████████████████████████████████████████| 1600000/1600000 [04:20<00:00, 6141.95tweet/s]
# Preprocessing completed in 260.51 seconds

# %%
processed_text
# Out:
# ['USER URL aww that s a bummer you shoulda got david carr of third day to do it d ',
#  'is upset that he can t update his facebook by texting it and might cry a a result school today also blah ',
#  'USER i dived many time for the ball managed to save 50 the rest go out of bound ',
#  'my whole body feel itchy and like it on fire ',
#  'USER no it s not behaving at all i m mad why am i here because i can t see you all over there ',
#  'USER not the whole crew ',
#  'need a hug ',
#  'USER hey long time no see yes rain a bit only a bit lol i m fine thanks how s you ',
#  'USER nope they didn t have it ',
#  'USER que me muera ',
#  'spring break in plain city it s snowing ',
#  'i just re pierced my ear ',
#  'USER i couldn t bear to watch it and i thought the ua loss wa embarrassing ',
#  'USER it it count idk why i did either you never talk to me anymore ',
#  'USER i would ve been the first but i didn t have a gun not really though zac snyder s just a doucheclown ',
# ...

# %% [markdown]
# # Feature Extraction : TfidfVectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import time
from tqdm import tqdm
from sklearn.model_selection import train_test_split

# Initialize the TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(max_features=10000, stop_words='english', ngram_range=(1, 2), min_df=5, max_df=0.8)

# Measure the time taken for vectorization
start_time = time.time()

X_tfidf = tfidf_vectorizer.fit_transform(tqdm(processed_text, desc="Vectorizing text data", unit="document"))

end_time = time.time()
print(f"Vectorization completed in {end_time - start_time:.2f} seconds")

# Split the data into training and testing sets
start_time = time.time()

X_train_tfidf, X_test_tfidf, y_train, y_test = train_test_split(X_tfidf, dataset['sentiment'].values, test_size=0.2, random_state=0)

end_time = time.time()
print(f"Data splitting completed in {end_time - start_time:.2f} seconds")
# Out:
# Vectorizing text data: 100%|█████████████████████████████████████████| 1600000/1600000 [03:24<00:00, 7813.76document/s]
# Vectorization completed in 231.93 seconds
# Data splitting completed in 0.42 seconds

# %% [markdown]
# # Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# Define the model evaluation function
def model_Evaluate(model):
    y_pred = model.predict(X_test_tfidf)
    print("Classification Report:\n", classification_report(y_test, y_pred))
    print("Accuracy:", accuracy_score(y_test, y_pred))
    
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # Plot the confusion matrix
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

# %%
# Initialize and train the Logistic Regression model
LRmodel = LogisticRegression(C=0.1, max_iter=1000, solver='sag', tol=0.0001, class_weight='balanced', n_jobs=-1)
LRmodel.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000, n_jobs=-1,
#                    solver='sag')

# %%
# Evaluate the model
model_Evaluate(LRmodel)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77    159815
#            1       0.77      0.80      0.78    160185
#
#     accuracy                           0.78    320000
#    macro avg       0.78      0.78      0.78    320000
# weighted avg       0.78      0.78      0.78    320000
#
# Accuracy: 0.777846875

# %% [markdown]
# # Customized Grid search

# %% [raw]
# from tqdm import tqdm
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# import seaborn as sns
# import matplotlib.pyplot as plt
#
#
# param_grid = {
#
#     'C': [0.01, 0.1, 1, 10, 100],
#     'max_iter': [1000],
#     'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag'],
#     'penalty': ['l2'],# Note: 'l1' is not supported by some solvers
#     'tol': [1e-4, 1e-3],
#     'class_weight': [None, 'balanced']
#
# }
#
#
# best_params = None
# best_accuracy = 0
#
#
# total_iterations = len(param_grid['C']) * len(param_grid['max_iter']) * len(param_grid['solver']) * len(param_grid['tol']) * len(param_grid['class_weight'])
# progress_bar = tqdm(total=total_iterations, desc="Searching for best parameters", unit="iteration")
#
# for C in param_grid['C']:
#     for max_iter in param_grid['max_iter']:
#         for solver in param_grid['solver']:
#             for tol in param_grid['tol']:
#                 for class_weight in param_grid['class_weight']:
#                     try:
#                         # Initialize the Logistic Regression model with current parameters
#                         model = LogisticRegression(C=C, max_iter=max_iter, solver=solver, tol=tol, class_weight=class_weight, n_jobs=-1)
#
#                         # Train the model
#                         model.fit(X_train_tfidf, y_train)
#
#                         # Predict on the test set
#                         y_pred = model.predict(X_test_tfidf)
#
#                         # Calculate accuracy
#                         accuracy = accuracy_score(y_test, y_pred)
#
#                         # Update best parameters and accuracy if current model is better
#                         if accuracy > best_accuracy:
#                             best_accuracy = accuracy
#                             best_params = {'C': C, 'max_iter': max_iter, 'solver': solver, 'tol': tol, 'class_weight': class_weight}
#
#                         print(f"Parameters: C={C}, max_iter={max_iter}, solver={solver}, tol={tol}, class_weight={class_weight} - Accuracy: {accuracy:.4f}")
#                     except Exception as e:
#                         print(f"Error with parameters: C={C}, max_iter={max_iter}, solver={solver}, tol={tol}, class_weight={class_weight} - {e}")
#                     finally:
#                         progress_bar.update(1)
#
# progress_bar.close()
# print(f"Best Parameters: {best_params}")
# print(f"Best Accuracy: {best_accuracy:.4f}")
#
# best_model = LogisticRegression(**best_params, n_jobs=-1)
# best_model.fit(X_train_tfidf, y_train)
#
# def model_Evaluate(model):
#     y_pred = model.predict(X_test_tfidf)
#     print("Classification Report:\n", classification_report(y_test, y_pred))
#     print("Accuracy:", accuracy_score(y_test, y_pred))
#
#     # Compute the confusion matrix
#     cm = confusion_matrix(y_test, y_pred)
#
#     # Plot the confusion matrix
#     plt.figure(figsize=(10, 7))
#     sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
#     plt.xlabel('Predicted')
#     plt.ylabel('Actual')
#     plt.title('Confusion Matrix')
#     plt.show()
#
# # Evaluate the best model
# model_Evaluate(best_model)

# %% [raw]
# Searching for best parameters:   1%|▏         | 1/80 [00:04<06:33,  4.98s/iteration]Parameters: C=0.01, max_iter=1000, solver=newton-cg, tol=0.0001, class_weight=None - Accuracy: 0.7497
# Searching for best parameters:   2%|▎         | 2/80 [00:08<05:13,  4.02s/iteration]Parameters: C=0.01, max_iter=1000, solver=newton-cg, tol=0.0001, class_weight=balanced - Accuracy: 0.7498
# Searching for best parameters:   4%|▍         | 3/80 [00:10<04:18,  3.36s/iteration]Parameters: C=0.01, max_iter=1000, solver=newton-cg, tol=0.001, class_weight=None - Accuracy: 0.7497
# Searching for best parameters:   5%|▌         | 4/80 [00:13<04:03,  3.20s/iteration]Parameters: C=0.01, max_iter=1000, solver=newton-cg, tol=0.001, class_weight=balanced - Accuracy: 0.7498
# Searching for best parameters:   6%|▋         | 5/80 [00:16<03:43,  2.98s/iteration]Parameters: C=0.01, max_iter=1000, solver=lbfgs, tol=0.0001, class_weight=None - Accuracy: 0.7497
# Searching for best parameters:   8%|▊         | 6/80 [00:18<03:20,  2.71s/iteration]Parameters: C=0.01, max_iter=1000, solver=lbfgs, tol=0.0001, class_weight=balanced - Accuracy: 0.7498
# Searching for best parameters:   9%|▉         | 7/80 [00:20<03:04,  2.53s/iteration]Parameters: C=0.01, max_iter=1000, solver=lbfgs, tol=0.001, class_weight=None - Accuracy: 0.7497
# Searching for best parameters:  10%|█         | 8/80 [00:22<02:53,  2.41s/iteration]Parameters: C=0.01, max_iter=1000, solver=lbfgs, tol=0.001, class_weight=balanced - Accuracy: 0.7498
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  11%|█▏        | 9/80 [00:24<02:30,  2.11s/iteration]Parameters: C=0.01, max_iter=1000, solver=liblinear, tol=0.0001, class_weight=None - Accuracy: 0.7497
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  12%|█▎        | 10/80 [00:25<02:13,  1.91s/iteration]Parameters: C=0.01, max_iter=1000, solver=liblinear, tol=0.0001, class_weight=balanced - Accuracy: 0.7498
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  14%|█▍        | 11/80 [00:27<02:05,  1.82s/iteration]Parameters: C=0.01, max_iter=1000, solver=liblinear, tol=0.001, class_weight=None - Accuracy: 0.7497
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  15%|█▌        | 12/80 [00:29<02:17,  2.02s/iteration]Parameters: C=0.01, max_iter=1000, solver=liblinear, tol=0.001, class_weight=balanced - Accuracy: 0.7498
# Searching for best parameters:  16%|█▋        | 13/80 [00:34<03:08,  2.81s/iteration]Parameters: C=0.01, max_iter=1000, solver=sag, tol=0.0001, class_weight=None - Accuracy: 0.7497
# Searching for best parameters:  18%|█▊        | 14/80 [00:38<03:35,  3.27s/iteration]Parameters: C=0.01, max_iter=1000, solver=sag, tol=0.0001, class_weight=balanced - Accuracy: 0.7498
# Searching for best parameters:  19%|█▉        | 15/80 [00:42<03:35,  3.32s/iteration]Parameters: C=0.01, max_iter=1000, solver=sag, tol=0.001, class_weight=None - Accuracy: 0.7497
# Searching for best parameters:  20%|██        | 16/80 [00:47<04:10,  3.92s/iteration]Parameters: C=0.01, max_iter=1000, solver=sag, tol=0.001, class_weight=balanced - Accuracy: 0.7498
# Searching for best parameters:  21%|██▏       | 17/80 [00:51<04:04,  3.88s/iteration]Parameters: C=0.1, max_iter=1000, solver=newton-cg, tol=0.0001, class_weight=None - Accuracy: 0.7688
# Searching for best parameters:  22%|██▎       | 18/80 [00:54<03:54,  3.78s/iteration]Parameters: C=0.1, max_iter=1000, solver=newton-cg, tol=0.0001, class_weight=balanced - Accuracy: 0.7688
# Searching for best parameters:  24%|██▍       | 19/80 [00:59<03:56,  3.88s/iteration]Parameters: C=0.1, max_iter=1000, solver=newton-cg, tol=0.001, class_weight=None - Accuracy: 0.7688
# Searching for best parameters:  25%|██▌       | 20/80 [01:02<03:52,  3.87s/iteration]Parameters: C=0.1, max_iter=1000, solver=newton-cg, tol=0.001, class_weight=balanced - Accuracy: 0.7688
# Searching for best parameters:  26%|██▋       | 21/80 [01:08<04:11,  4.27s/iteration]Parameters: C=0.1, max_iter=1000, solver=lbfgs, tol=0.0001, class_weight=None - Accuracy: 0.7688
# Searching for best parameters:  28%|██▊       | 22/80 [01:14<04:40,  4.83s/iteration]Parameters: C=0.1, max_iter=1000, solver=lbfgs, tol=0.0001, class_weight=balanced - Accuracy: 0.7688
# Searching for best parameters:  29%|██▉       | 23/80 [01:19<04:39,  4.90s/iteration]Parameters: C=0.1, max_iter=1000, solver=lbfgs, tol=0.001, class_weight=None - Accuracy: 0.7688
# Searching for best parameters:  30%|███       | 24/80 [01:24<04:40,  5.00s/iteration]Parameters: C=0.1, max_iter=1000, solver=lbfgs, tol=0.001, class_weight=balanced - Accuracy: 0.7688
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  31%|███▏      | 25/80 [01:29<04:26,  4.84s/iteration]Parameters: C=0.1, max_iter=1000, solver=liblinear, tol=0.0001, class_weight=None - Accuracy: 0.7688
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  32%|███▎      | 26/80 [01:31<03:39,  4.07s/iteration]Parameters: C=0.1, max_iter=1000, solver=liblinear, tol=0.0001, class_weight=balanced - Accuracy: 0.7688
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:
/iteration]Parameters: C=10, max_iter=1000, solver=sag, tol=0.0001, class_weight=balanced - Accuracy: 0.7704
# Searching for best parameters:  79%|███████▉  | 63/80 [07:08<02:56, 10.40s/iteration]Parameters: C=10, max_iter=1000, solver=sag, tol=0.001, class_weight=None - Accuracy: 0.7704
# Searching for best parameters:  80%|████████  | 64/80 [07:17<02:36,  9.78s/iteration]Parameters: C=10, max_iter=1000, solver=sag, tol=0.001, class_weight=balanced - Accuracy: 0.7704
# Searching for best parameters:  81%|████████▏ | 65/80 [07:37<03:12, 12.86s/iteration]Parameters: C=100, max_iter=1000, solver=newton-cg, tol=0.0001, class_weight=None - Accuracy: 0.7701
# Searching for best parameters:  82%|████████▎ | 66/80 [07:58<03:34, 15.33s/iteration]Parameters: C=100, max_iter=1000, solver=newton-cg, tol=0.0001, class_weight=balanced - Accuracy: 0.7701
# Searching for best parameters:  84%|████████▍ | 67/80 [08:15<03:28, 16.02s/iteration]Parameters: C=100, max_iter=1000, solver=newton-cg, tol=0.001, class_weight=None - Accuracy: 0.7701
# Searching for best parameters:  85%|████████▌ | 68/80 [08:32<03:14, 16.17s/iteration]Parameters: C=100, max_iter=1000, solver=newton-cg, tol=0.001, class_weight=balanced - Accuracy: 0.7701
# Searching for best parameters:  86%|████████▋ | 69/80 [09:08<04:02, 22.07s/iteration]Parameters: C=100, max_iter=1000, solver=lbfgs, tol=0.0001, class_weight=None - Accuracy: 0.7702
# Searching for best parameters:  88%|████████▊ | 70/80 [09:46<04:28, 26.81s/iteration]Parameters: C=100, max_iter=1000, solver=lbfgs, tol=0.0001, class_weight=balanced - Accuracy: 0.7701
# Searching for best parameters:  89%|████████▉ | 71/80 [10:20<04:21, 29.01s/iteration]Parameters: C=100, max_iter=1000, solver=lbfgs, tol=0.001, class_weight=None - Accuracy: 0.7702
# Searching for best parameters:  90%|█████████ | 72/80 [10:58<04:14, 31.83s/iteration]Parameters: C=100, max_iter=1000, solver=lbfgs, tol=0.001, class_weight=balanced - Accuracy: 0.7701
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  91%|█████████▏| 73/80 [11:26<03:34, 30.65s/iteration]Parameters: C=100, max_iter=1000, solver=liblinear, tol=0.0001, class_weight=None - Accuracy: 0.7701
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  92%|█████████▎| 74/80 [11:49<02:50, 28.43s/iteration]Parameters: C=100, max_iter=1000, solver=liblinear, tol=0.0001, class_weight=balanced - Accuracy: 0.7701
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  94%|█████████▍| 75/80 [12:06<02:04, 24.98s/iteration]Parameters: C=100, max_iter=1000, solver=liblinear, tol=0.001, class_weight=None - Accuracy: 0.7701
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  95%|█████████▌| 76/80 [12:23<01:30, 22.64s/iteration]Parameters: C=100, max_iter=1000, solver=liblinear, tol=0.001, class_weight=balanced - Accuracy: 0.7701
# Searching for best parameters:  96%|█████████▋| 77/80 [13:03<01:23, 27.80s/iteration]Parameters: C=100, max_iter=1000, solver=sag, tol=0.0001, class_weight=None - Accuracy: 0.7701
# Searching for best parameters:  98%|█████████▊| 78/80 [13:42<01:01, 30.95s/iteration]Parameters: C=100, max_iter=1000, solver=sag, tol=0.0001, class_weight=balanced - Accuracy: 0.7701
# Searching for best parameters:  99%|█████████▉| 79/80 [14:00<00:27, 27.28s/iteration]Parameters: C=100, max_iter=1000, solver=sag, tol=0.001, class_weight=None - Accuracy: 0.7701
# Searching for best parameters: 100%|██████████| 80/80 [14:19<00:00, 10.75s/iteration]Parameters: C=100, max_iter=1000, solver=sag, tol=0.001, class_weight=balanced - Accuracy: 0.7701

# %% [raw]
# Best Parameters: {'C': 1, 'max_iter': 1000, 'solver': 'newton-cg', 'tol': 0.0001, 'class_weight': 'balanced'}
# Best Accuracy: 0.7723

# %% [markdown]
# # Logistic Regression + TfidfVectorizer model with best parameters

# %%
LRmodel = LogisticRegression(C=1, max_iter=1000, solver='newton-cg', tol=0.0001, class_weight='balanced', n_jobs=-1)
LRmodel.fit(X_train_tfidf, y_train) # Train the model on the training data
# Out:
# LogisticRegression(C=1, class_weight='balanced', max_iter=1000, n_jobs=-1,
#                    solver='newton-cg')

# %%
model_Evaluate(LRmodel)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.75      0.77    159815
#            1       0.77      0.81      0.79    160185
#
#     accuracy                           0.78    320000
#    macro avg       0.78      0.78      0.78    320000
# weighted avg       0.78      0.78      0.78    320000
#
# Accuracy: 0.77951875
