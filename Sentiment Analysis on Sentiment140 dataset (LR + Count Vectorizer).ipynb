# %% [markdown]
# # Libraries

# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import re
from nltk.stem import WordNetLemmatizer
from tqdm import tqdm
import time
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
import seaborn as sns

# %% [markdown]
# # Loading the data

# %%
DATASET_COLUMNS  = ["sentiment", "ids", "date", "flag", "user", "text"]
DATASET_ENCODING = "ISO-8859-1"
dataset = pd.read_csv('C:/Users/IDEH/Desktop/Sentimental/Data/Sentiment140.csv',
                      encoding=DATASET_ENCODING , names=DATASET_COLUMNS)
dataset
# Out:
#          sentiment         ids                          date      flag  \
# 0                0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1                0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2                0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3                0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4                0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...            ...         ...                           ...       ...
# 1599995          4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996          4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997          4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998          4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999          4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                               text
# ...

# %% [markdown]
# Data Preprocessing

# %%
dataset = dataset[['sentiment','text']]
sentiment_counts = dataset['sentiment'].value_counts()
print(sentiment_counts)
# Out:
# 0    800000
# 4    800000
# Name: sentiment, dtype: int64

# %%
# Map sentiment labels to integers (0: negative, 4: positive)
sentiment_map = {0: 0, 4: 1}  # 0: negative, 1: positive
dataset.loc[:, 'sentiment'] = dataset['sentiment'].map(sentiment_map)
# Out:
# C:\Users\IDEH\AppData\Local\Temp\ipykernel_16696\2550957762.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.loc[:, 'sentiment'] = dataset['sentiment'].map(sentiment_map)

# %%
sentiment_counts = dataset['sentiment'].value_counts()
print(sentiment_counts)
import matplotlib.pyplot as plt

# Assuming sentiment_counts is a pandas Series
sentiment_counts = dataset['sentiment'].value_counts()

# Plotting the bar chart
plt.figure(figsize=(10, 6))
sentiment_counts.plot(kind='bar', color='skyblue')
plt.title('Sentiment Distribution')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
plt.xticks(rotation=0)
plt.show()
# Out:
# 0    800000
# 1    800000
# Name: sentiment, dtype: int64

# %% [markdown]
# # Preprocessing

# %%
import re
from nltk.stem import WordNetLemmatizer
from tqdm import tqdm
import time

# Define your custom preprocessing function with tqdm and time
def preprocess(textdata):
    processedText = []
    wordLemm = WordNetLemmatizer()
    urlPattern = r"((http://)[^ ]*|(https://)[^ ]*|( www\.)[^ ]*)"
    userPattern = '@[^\s]+'
    alphaPattern = "[^a-zA-Z0-9]"
    sequencePattern = r"(.)\1\1+"
    seqReplacePattern = r"\1\1"
    
    start_time = time.time()
    
    for tweet in tqdm(textdata, desc="Processing tweets", unit="tweet"):
        tweet = tweet.lower()
        tweet = re.sub(urlPattern, ' URL', tweet)
        tweet = re.sub(userPattern, ' USER', tweet)
        tweet = re.sub(alphaPattern, " ", tweet)
        tweet = re.sub(sequencePattern, seqReplacePattern, tweet)
        tweetwords = ''
        for word in tweet.split():
            word = wordLemm.lemmatize(word)
            tweetwords += (word + ' ')
        processedText.append(tweetwords)
    
    end_time = time.time()
    print(f"Preprocessing completed in {end_time - start_time:.2f} seconds")
    
    return processedText

# Apply the preprocessing function to the text data
processed_text = preprocess(dataset['text'].values)
# Out:
# Processing tweets: 100%|████████████████████████████████████████████████| 1600000/1600000 [05:10<00:00, 5151.78tweet/s]
# Preprocessing completed in 310.58 seconds

# %%
processed_text
# Out:
# ['USER URL aww that s a bummer you shoulda got david carr of third day to do it d ',
#  'is upset that he can t update his facebook by texting it and might cry a a result school today also blah ',
#  'USER i dived many time for the ball managed to save 50 the rest go out of bound ',
#  'my whole body feel itchy and like it on fire ',
#  'USER no it s not behaving at all i m mad why am i here because i can t see you all over there ',
#  'USER not the whole crew ',
#  'need a hug ',
#  'USER hey long time no see yes rain a bit only a bit lol i m fine thanks how s you ',
#  'USER nope they didn t have it ',
#  'USER que me muera ',
#  'spring break in plain city it s snowing ',
#  'i just re pierced my ear ',
#  'USER i couldn t bear to watch it and i thought the ua loss wa embarrassing ',
#  'USER it it count idk why i did either you never talk to me anymore ',
#  'USER i would ve been the first but i didn t have a gun not really though zac snyder s just a doucheclown ',
# ...

# %% [markdown]
# # Feature Extraction : CountVectorizer

# %%
# Initialize the CountVectorizer
count_vectorizer = CountVectorizer(max_features=10000, stop_words='english', ngram_range=(1, 2), min_df=5, max_df=0.8)

# Measure the time taken for vectorization
start_time = time.time()

X_counts = count_vectorizer.fit_transform(tqdm(processed_text, desc="Vectorizing text data", unit="document"))

end_time = time.time()
print(f"Vectorization completed in {end_time - start_time:.2f} seconds")

# Split the data into training and testing sets
start_time = time.time()

X_train_counts, X_test_counts, y_train, y_test = train_test_split(X_counts, dataset['sentiment'].values, test_size=0.2, random_state=0)

end_time = time.time()
print(f"Data splitting completed in {end_time - start_time:.2f} seconds")
# Out:
# Vectorizing text data: 100%|████████████████████████████████████████| 1600000/1600000 [01:10<00:00, 22805.84document/s]
# Vectorization completed in 100.14 seconds
# Data splitting completed in 0.45 seconds

# %% [markdown]
# # Model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# Define the model evaluation function
def model_Evaluate(model):
    y_pred = model.predict(X_test_counts)
    print("Classification Report:\n", classification_report(y_test, y_pred))
    print("Accuracy:", accuracy_score(y_test, y_pred))
    
    # Compute the confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    
    # Plot the confusion matrix
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

# %%
# Initialize and train the Logistic Regression model
LRmodel = LogisticRegression(C=2, max_iter=1000, n_jobs=-1)
LRmodel.fit(X_train_counts, y_train) # Train the model on the training data
# Out:
# LogisticRegression(C=2, max_iter=1000, n_jobs=-1)

# %%
# Evaluate the model
model_Evaluate(LRmodel)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.76      0.77    159815
#            1       0.77      0.80      0.79    160185
#
#     accuracy                           0.78    320000
#    macro avg       0.78      0.78      0.78    320000
# weighted avg       0.78      0.78      0.78    320000
#
# Accuracy: 0.779990625

# %% [markdown]
# # Customized Grid search

# %% [raw]
# from tqdm import tqdm
# from sklearn.linear_model import LogisticRegression
# from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# import seaborn as sns
# import matplotlib.pyplot as plt
#
#
# param_grid = {
#
#     'C': [0.01, 0.1, 1, 10, 100],
#     'max_iter': [1000],
#     'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag'],
#     'penalty': ['l2'],# Note: 'l1' is not supported by some solvers
#     'tol': [1e-4, 1e-3],
#     'class_weight': [None, 'balanced']
#
# }
#
#
# best_params = None
# best_accuracy = 0
#
#
# total_iterations = len(param_grid['C']) * len(param_grid['max_iter']) * len(param_grid['solver']) * len(param_grid['tol']) * len(param_grid['class_weight'])
# progress_bar = tqdm(total=total_iterations, desc="Searching for best parameters", unit="iteration")
#
# for C in param_grid['C']:
#     for max_iter in param_grid['max_iter']:
#         for solver in param_grid['solver']:
#             for tol in param_grid['tol']:
#                 for class_weight in param_grid['class_weight']:
#                     try:
#                         # Initialize the Logistic Regression model with current parameters
#                         model = LogisticRegression(C=C, max_iter=max_iter, solver=solver, tol=tol, class_weight=class_weight, n_jobs=-1)
#
#                         # Train the model
#                         model.fit(X_train_counts, y_train)
#
#                         # Predict on the test set
#                         y_pred = model.predict(X_test_counts)
#
#                         # Calculate accuracy
#                         accuracy = accuracy_score(y_test, y_pred)
#
#                         # Update best parameters and accuracy if current model is better
#                         if accuracy > best_accuracy:
#                             best_accuracy = accuracy
#                             best_params = {'C': C, 'max_iter': max_iter, 'solver': solver, 'tol': tol, 'class_weight': class_weight}
#
#                         print(f"Parameters: C={C}, max_iter={max_iter}, solver={solver}, tol={tol}, class_weight={class_weight} - Accuracy: {accuracy:.4f}")
#                     except Exception as e:
#                         print(f"Error with parameters: C={C}, max_iter={max_iter}, solver={solver}, tol={tol}, class_weight={class_weight} - {e}")
#                     finally:
#                         progress_bar.update(1)
#
# progress_bar.close()
# print(f"Best Parameters: {best_params}")
# print(f"Best Accuracy: {best_accuracy:.4f}")
#
# best_model = LogisticRegression(**best_params, n_jobs=-1)
# best_model.fit(X_train_counts, y_train)
#
# def model_Evaluate(model):
#     y_pred = model.predict(X_test_counts)
#     print("Classification Report:\n", classification_report(y_test, y_pred))
#     print("Accuracy:", accuracy_score(y_test, y_pred))
#
#     # Compute the confusion matrix
#     cm = confusion_matrix(y_test, y_pred)
#
#     # Plot the confusion matrix
#     plt.figure(figsize=(10, 7))
#     sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Negative', 'Positive'], yticklabels=['Negative', 'Positive'])
#     plt.xlabel('Predicted')
#     plt.ylabel('Actual')
#     plt.title('Confusion Matrix')
#     plt.show()
#
# # Evaluate the best model
# model_Evaluate(best_model)

# %% [raw]
# Searching for best parameters:   1%|          | 1/100 [00:13<23:05, 14.00s/iteration]
# Searching for best parameters:   1%|          | 1/100 [00:04<07:07,  4.31s/iteration]Parameters: C=0.01, max_iter=1000, solver=newton-cg, tol=0.0001, class_weight=None - Accuracy: 0.7593
# Searching for best parameters:   2%|▏         | 2/100 [00:08<07:17,  4.46s/iteration]Parameters: C=0.01, max_iter=1000, solver=newton-cg, tol=0.0001, class_weight=balanced - Accuracy: 0.7594
# Searching for best parameters:   3%|▎         | 3/100 [00:13<07:26,  4.60s/iteration]Parameters: C=0.01, max_iter=1000, solver=newton-cg, tol=0.001, class_weight=None - Accuracy: 0.7593
# Searching for best parameters:   4%|▍         | 4/100 [00:17<06:37,  4.14s/iteration]Parameters: C=0.01, max_iter=1000, solver=newton-cg, tol=0.001, class_weight=balanced - Accuracy: 0.7594
# Searching for best parameters:   5%|▌         | 5/100 [00:20<06:15,  3.95s/iteration]Parameters: C=0.01, max_iter=1000, solver=lbfgs, tol=0.0001, class_weight=None - Accuracy: 0.7593
# Searching for best parameters:   6%|▌         | 6/100 [00:24<06:14,  3.99s/iteration]Parameters: C=0.01, max_iter=1000, solver=lbfgs, tol=0.0001, class_weight=balanced - Accuracy: 0.7595
# Searching for best parameters:   7%|▋         | 7/100 [00:28<06:00,  3.88s/iteration]Parameters: C=0.01, max_iter=1000, solver=lbfgs, tol=0.001, class_weight=None - Accuracy: 0.7593
# Searching for best parameters:   8%|▊         | 8/100 [00:32<05:53,  3.84s/iteration]Parameters: C=0.01, max_iter=1000, solver=lbfgs, tol=0.001, class_weight=balanced - Accuracy: 0.7595
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:   9%|▉         | 9/100 [00:34<05:09,  3.40s/iteration]Parameters: C=0.01, max_iter=1000, solver=liblinear, tol=0.0001, class_weight=None - Accuracy: 0.7593
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  10%|█         | 10/100 [00:39<05:48,  3.87s/iteration]Parameters: C=0.01, max_iter=1000, solver=liblinear, tol=0.0001, class_weight=balanced - Accuracy: 0.7594
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  11%|█         | 11/100 [00:41<04:51,  3.27s/iteration]Parameters: C=0.01, max_iter=1000, solver=liblinear, tol=0.001, class_weight=None - Accuracy: 0.7593
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  12%|█▏        | 12/100 [00:43<04:14,  2.89s/iteration]Parameters: C=0.01, max_iter=1000, solver=liblinear, tol=0.001, class_weight=balanced - Accuracy: 0.7594
# Searching for best parameters:  13%|█▎        | 13/100 [00:46<04:21,  3.01s/iteration]Parameters: C=0.01, max_iter=1000, solver=sag, tol=0.0001, class_weight=None - Accuracy: 0.7593
# Searching for best parameters:  14%|█▍        | 14/100 [00:50<04:31,  3.15s/iteration]Parameters: C=0.01, max_iter=1000, solver=sag, tol=0.0001, class_weight=balanced - Accuracy: 0.7594
# Searching for best parameters:  15%|█▌        | 15/100 [00:52<04:13,  2.98s/iteration]Parameters: C=0.01, max_iter=1000, solver=sag, tol=0.001, class_weight=None - Accuracy: 0.7593
# Searching for best parameters:  16%|█▌        | 16/100 [00:54<03:48,  2.73s/iteration]Parameters: C=0.01, max_iter=1000, solver=sag, tol=0.001, class_weight=balanced - Accuracy: 0.7594
# Searching for best parameters:  17%|█▋        | 17/100 [01:00<05:08,  3.71s/iteration]Parameters: C=0.01, max_iter=1000, solver=saga, tol=0.0001, class_weight=None - Accuracy: 0.7594
# Searching for best parameters:  18%|█▊        | 18/100 [01:08<06:27,  4.72s/iteration]Parameters: C=0.01, max_iter=1000, solver=saga, tol=0.0001, class_weight=balanced - Accuracy: 0.7594
# Searching for best parameters:  19%|█▉        | 19/100 [01:11<05:50,  4.33s/iteration]Parameters: C=0.01, max_iter=1000, solver=saga, tol=0.001, class_weight=None - Accuracy: 0.7593
# Searching for best parameters:  20%|██        | 20/100 [01:15<05:30,  4.13s/iteration]Parameters: C=0.01, max_iter=1000, solver=saga, tol=0.001, class_weight=balanced - Accuracy: 0.7594
# Searching for best parameters:  21%|██        | 21/100 [01:21<06:26,  4.90s/iteration]Parameters: C=0.1, max_iter=1000, solver=newton-cg, tol=0.0001, class_weight=None - Accuracy: 0.7758
# Searching for best parameters:  22%|██▏       | 22/100 [01:27<06:32,  5.03s/iteration]Parameters: C=0.1, max_iter=1000, solver=newton-cg, tol=0.0001, class_weight=balanced - Accuracy: 0.7759
# Searching for best parameters:  23%|██▎       | 23/100 [01:33<06:58,  5.44s/iteration]Parameters: C=0.1, max_iter=1000, solver=newton-cg, tol=0.001, class_weight=None - Accuracy: 0.7758
# Searching for best parameters:  24%|██▍       | 24/100 [01:38<06:43,  5.31s/iteration]Parameters: C=0.1, max_iter=1000, solver=newton-cg, tol=0.001, class_weight=balanced - Accuracy: 0.7759
# Searching for best parameters:  25%|██▌       | 25/100 [01:45<07:12,  5.76s/iteration]Parameters: C=0.1, max_iter=1000, solver=lbfgs, tol=0.0001, class_weight=None - Accuracy: 0.7758
# Searching for best parameters:  26%|██▌       | 26/100 [01:52<07:29,  6.07s/iteration]Parameters: C=0.1, max_iter=1000, solver=lbfgs, tol=0.0001, class_weight=balanced - Accuracy: 0.7759
# Searching for best parameters:  27%|██▋       | 27/100 [01:59<07:48,  6.42s/iteration]Parameters: C=0.1, max_iter=1000, solver=lbfgs, tol=0.001, class_weight=None - Accuracy: 0.7758
# Searching for best parameters:  28%|██▊       | 28/100 [02:06<07:49,  6.52s/iteration]Parameters: C=0.1, max_iter=1000, solver=lbfgs, tol=0.001, class_weight=balanced - Accuracy: 0.7759
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  29%|██▉       | 29/100 [02:13<07:52,  6.65s/iteration]Parameters: C=0.1, max_iter=1000, solver=liblinear, tol=0.0001, class_weight=None - Accuracy: 0.7758
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  30%|███       | 30/100 [02:17<07:07,  6.10s/iteration]Parameters: C=0.1, max_iter=1000, solver=liblinear, tol=0.0001, class_weight=balanced - Accuracy: 0.7759
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  31%|███       | 31/100 [02:21<06:12,  5.39s/iteration]Parameters: C=0.1, max_iter=1000, solver=liblinear, tol=0.001, class_weight=None - Accuracy: 0.7758
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  32%|███▏      | 32/100 [02:29<07:01,  6.20s/iteration]Parameters: C=0.1, max_iter=1000, solver=liblinear, tol=0.001, class_weight=balanced - Accuracy: 0.7759
# Searching for best parameters:  33%|███▎      | 33/100 [02:47<10:49,  9.70s/iteration]Parameters: C=0.1, max_iter=1000, solver=sag, tol=0.0001, class_weight=None - Accuracy: 0.7757
# Searching for best parameters:  34%|███▍      | 34/100 [03:06<13:42, 12.47s/iteration]Parameters: C=0.1, max_iter=1000, solver=sag, tol=0.0001, class_weight=balanced - Accuracy: 0.7759
# Searching for best parameters:  35%|███▌      | 35/100 [03:16<12:32, 11.58s/iteration]Parameters: C=0.1, max_iter=1000, solver=sag, tol=0.001, class_weight=None - Accuracy: 0.7757
# Searching for best parameters:  36%|███▌      | 36/100 [03:25<11:44, 11.01s/iteration]Parameters: C=0.1, max_iter=1000, solver=sag, tol=0.001, class_weight=balanced - Accuracy: 0.7758
# Searching for best parameters:  37%|███▋      | 37/100 [03:58<18:17, 17.42s/iteration]Parameters: C=0.1, max_iter=1000, solver=saga, tol=0.0001, class_weight=None - Accuracy: 0.7758
# Searching for best parameters:  38%|███▊      | 38/100 [04:32<23:11, 22.45s/iteration]Parameters: C=0.1, max_iter=1000, solver=saga, tol=0.0001, class_weight=balanced - Accuracy: 0.7758
# Searching for best parameters:  39%|███▉      | 39/100 [04:48<21:03, 20.72s/iteration]Parameters: C=0.1, max_iter=1000, solver=saga, tol=0.001, class_weight=None - Accuracy: 0.7756
# Searching for best parameters:  40%|████      | 40/100 [05:05<19:32, 19.54s/iteration]Parameters: C=0.1, max_iter=1000, solver=saga, tol=0.001, class_weight=balanced - Accuracy: 0.7757
# Searching for best parameters:  41%|████      | 41/100 [05:16<16:35, 16.87s/iteration]Parameters: C=1, max_iter=1000, solver=newton-cg, tol=0.0001, class_weight=None - Accuracy: 0.7756
# Searching for best parameters:  42%|████▏     | 42/100 [05:28<14:47, 15.30s/iteration]Parameters: C=1, max_iter=1000, solver=newton-cg, tol=0.0001, class_weight=balanced - Accuracy: 0.7756
# Searching for best parameters:  43%|████▎     | 43/100 [05:37<12:52, 13.56s/iteration]Parameters: C=1, max_iter=1000, solver=newton-cg, tol=0.001, class_weight=None - Accuracy: 0.7756
# Searching for best parameters:  44%|████▍     | 44/100 [05:46<11:21, 12.16s/iteration]Parameters: C=1, max_iter=1000, solver=newton-cg, tol=0.001, class_weight=balanced - Accuracy: 0.7756
# Searching for best parameters:  45%|████▌     | 45/100 [05:59<11:24, 12.45s/iteration]Parameters: C=1, max_iter=1000, solver=lbfgs, tol=0.0001, class_weight=None - Accuracy: 0.7756
# Searching for best parameters:  46%|████▌     | 46/100 [06:13<11:31, 12.80s/iteration]Parameters: C=1, max_iter=1000, solver=lbfgs, tol=0.0001, class_weight=balanced - Accuracy: 0.7757
# Searching for best parameters:  47%|████▋     | 47/100 [06:26<11:24, 12.92s/iteration]Parameters: C=1, max_iter=1000, solver=lbfgs, tol=0.001, class_weight=None - Accuracy: 0.7756
# Searching for best parameters:  48%|████▊     | 48/100 [06:40<11:23, 13.15s/iteration]Parameters: C=1, max_iter=1000, solver=lbfgs, tol=0.001, class_weight=balanced - Accuracy: 0.7757
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  49%|████▉     | 49/100 [06:50<10:25, 12.26s/iteration]Parameters: C=1, max_iter=1000, solver=liblinear, tol=0.0001, class_weight=None - Accuracy: 0.7756
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  50%|█████     | 50/100 [07:01<10:03, 12.07s/iteration]Parameters: C=1, max_iter=1000, solver=liblinear, tol=0.0001, class_weight=balanced - Accuracy: 0.7757
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  51%|█████     | 51/100 [07:07<08:11, 10.04s/iteration]Parameters: C=1, max_iter=1000, solver=liblinear, tol=0.001, class_weight=None - Accuracy: 0.7756
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  52%|█████▏    | 52/100 [07:14<07:25,  9.28s/iteration]Parameters: C=1, max_iter=1000, solver=liblinear, tol=0.001, class_weight=balanced - Accuracy: 0.7756
# Searching for best parameters:  53%|█████▎    | 53/100 [08:23<21:12, 27.07s/iteration]Parameters: C=1, max_iter=1000, solver=sag, tol=0.0001, class_weight=None - Accuracy: 0.7757
# Searching for best parameters:  54%|█████▍    | 54/100 [09:40<32:17, 42.12s/iteration]Parameters: C=1, max_iter=1000, solver=sag, tol=0.0001, class_weight=balanced - Accuracy: 0.7757
# Searching for best parameters:  55%|█████▌    | 55/100 [10:16<30:12, 40.29s/iteration]Parameters: C=1, max_iter=1000, solver=sag, tol=0.001, class_weight=None - Accuracy: 0.7757
# Searching for best parameters:  56%|█████▌    | 56/100 [10:51<28:28, 38.83s/iteration]Parameters: C=1, max_iter=1000, solver=sag, tol=0.001, class_weight=balanced - Accuracy: 0.7756
# Searching for best parameters:  57%|█████▋    | 57/100 [12:54<45:43, 63.81s/iteration]Parameters: C=1, max_iter=1000, solver=saga, tol=0.0001, class_weight=None - Accuracy: 0.7756
# Searching for best parameters:  58%|█████▊    | 58/100 [14:54<56:34, 80.81s/iteration]Parameters: C=1, max_iter=1000, solver=saga, tol=0.0001, class_weight=balanced - Accuracy: 0.7757
# Searching for best parameters:  59%|█████▉    | 59/100 [15:45<49:05, 71.85s/iteration]Parameters: C=1, max_iter=1000, solver=saga, tol=0.001, class_weight=None - Accuracy: 0.7758
# Searching for best parameters:  60%|██████    | 60/100 [16:36<43:47, 65.68s/iteration]Parameters: C=1, max_iter=1000, solver=saga, tol=0.001, class_weight=balanced - Accuracy: 0.7756
# Searching for best parameters:  61%|██████    | 61/100 [17:01<34:38, 53.29s/iteration]Parameters: C=10, max_iter=1000, solver=newton-cg, tol=0.0001, class_weight=None - Accuracy: 0.7752
# Searching for best parameters:  62%|██████▏   | 62/100 [17:28<28:54, 45.66s/iteration]Parameters: C=10, max_iter=1000, solver=newton-cg, tol=0.0001, class_weight=balanced - Accuracy: 0.7751
# Searching for best parameters:  63%|██████▎   | 63/100 [17:47<23:04, 37.43s/iteration]Parameters: C=10, max_iter=1000, solver=newton-cg, tol=0.001, class_weight=None - Accuracy: 0.7752
# Searching for best parameters:  64%|██████▍   | 64/100 [18:06<19:11, 31.97s/iteration]Parameters: C=10, max_iter=1000, solver=newton-cg, tol=0.001, class_weight=balanced - Accuracy: 0.7751
# Searching for best parameters:  65%|██████▌   | 65/100 [18:28<16:53, 28.96s/iteration]Parameters: C=10, max_iter=1000, solver=lbfgs, tol=0.0001, class_weight=None - Accuracy: 0.7752
# Searching for best parameters:  66%|██████▌   | 66/100 [18:50<15:18, 27.01s/iteration]Parameters: C=10, max_iter=1000, solver=lbfgs, tol=0.0001, class_weight=balanced - Accuracy: 0.7751
# Searching for best parameters:  67%|██████▋   | 67/100 [19:13<14:03, 25.57s/iteration]Parameters: C=10, max_iter=1000, solver=lbfgs, tol=0.001, class_weight=None - Accuracy: 0.7752
# Searching for best parameters:  68%|██████▊   | 68/100 [19:34<12:58, 24.33s/iteration]Parameters: C=10, max_iter=1000, solver=lbfgs, tol=0.001, class_weight=balanced - Accuracy: 0.7751
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  69%|██████▉   | 69/100 [19:59<12:41, 24.57s/iteration]Parameters: C=10, max_iter=1000, solver=liblinear, tol=0.0001, class_weight=None - Accuracy: 0.7752
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  70%|███████   | 70/100 [20:37<14:18, 28.63s/iteration]Parameters: C=10, max_iter=1000, solver=liblinear, tol=0.0001, class_weight=balanced - Accuracy: 0.7751
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  71%|███████   | 71/100 [20:50<11:35, 23.99s/iteration]Parameters: C=10, max_iter=1000, solver=liblinear, tol=0.001, class_weight=None - Accuracy: 0.7751
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  72%|███████▏  | 72/100 [21:05<09:55, 21.26s/iteration]Parameters: C=10, max_iter=1000, solver=liblinear, tol=0.001, class_weight=balanced - Accuracy: 0.7751
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Searching for best parameters:  73%|███████▎  | 73/100 [23:42<27:53, 62.00s/iteration]Parameters: C=10, max_iter=1000, solver=sag, tol=0.0001, class_weight=None - Accuracy: 0.7752
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Searching for best parameters:  74%|███████▍  | 74/100 [26:23<39:45, 91.76s/iteration]Parameters: C=10, max_iter=1000, solver=sag, tol=0.0001, class_weight=balanced - Accuracy: 0.7752
# Searching for best parameters:  75%|███████▌  | 75/100 [27:05<31:58, 76.73s/iteration]Parameters: C=10, max_iter=1000, solver=sag, tol=0.001, class_weight=None - Accuracy: 0.7752
# Searching for best parameters:  76%|███████▌  | 76/100 [27:46<26:24, 66.01s/iteration]Parameters: C=10, max_iter=1000, solver=sag, tol=0.001, class_weight=balanced - Accuracy: 0.7752
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Searching for best parameters:  77%|███████▋  | 77/100 [30:39<37:34, 98.04s/iteration]Parameters: C=10, max_iter=1000, solver=saga, tol=0.0001, class_weight=None - Accuracy: 0.7752
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Searching for best parameters:  78%|███████▊  | 78/100 [33:31<44:06, 120.31s/iteration]Parameters: C=10, max_iter=1000, solver=saga, tol=0.0001, class_weight=balanced - Accuracy: 0.7752
# Searching for best parameters:  79%|███████▉  | 79/100 [34:32<35:51, 102.46s/iteration]Parameters: C=10, max_iter=1000, solver=saga, tol=0.001, class_weight=None - Accuracy: 0.7753
# Searching for best parameters:  80%|████████  | 80/100 [35:34<30:05, 90.26s/iteration] Parameters: C=10, max_iter=1000, solver=saga, tol=0.001, class_weight=balanced - Accuracy: 0.7754
# Searching for best parameters:  81%|████████  | 81/100 [36:39<26:10, 82.66s/iteration]Parameters: C=100, max_iter=1000, solver=newton-cg, tol=0.0001, class_weight=None - Accuracy: 0.7749
# Searching for best parameters:  82%|████████▏ | 82/100 [37:51<23:51, 79.55s/iteration]Parameters: C=100, max_iter=1000, solver=newton-cg, tol=0.0001, class_weight=balanced - Accuracy: 0.7749
# Searching for best parameters:  83%|████████▎ | 83/100 [38:39<19:49, 69.97s/iteration]Parameters: C=100, max_iter=1000, solver=newton-cg, tol=0.001, class_weight=None - Accuracy: 0.7749
# Searching for best parameters:  84%|████████▍ | 84/100 [39:26<16:49, 63.08s/iteration]Parameters: C=100, max_iter=1000, solver=newton-cg, tol=0.001, class_weight=balanced - Accuracy: 0.7749
# Searching for best parameters:  85%|████████▌ | 85/100 [39:55<13:12, 52.85s/iteration]Parameters: C=100, max_iter=1000, solver=lbfgs, tol=0.0001, class_weight=None - Accuracy: 0.7749
# Searching for best parameters:  86%|████████▌ | 86/100 [40:26<10:51, 46.51s/iteration]Parameters: C=100, max_iter=1000, solver=lbfgs, tol=0.0001, class_weight=balanced - Accuracy: 0.7750
# Searching for best parameters:  87%|████████▋ | 87/100 [40:56<08:59, 41.54s/iteration]Parameters: C=100, max_iter=1000, solver=lbfgs, tol=0.001, class_weight=None - Accuracy: 0.7749
# Searching for best parameters:  88%|████████▊ | 88/100 [41:28<07:41, 38.49s/iteration]Parameters: C=100, max_iter=1000, solver=lbfgs, tol=0.001, class_weight=balanced - Accuracy: 0.7750
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  89%|████████▉ | 89/100 [42:17<07:38, 41.68s/iteration]Parameters: C=100, max_iter=1000, solver=liblinear, tol=0.0001, class_weight=None - Accuracy: 0.7749
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  90%|█████████ | 90/100 [42:47<06:23, 38.31s/iteration]Parameters: C=100, max_iter=1000, solver=liblinear, tol=0.0001, class_weight=balanced - Accuracy: 0.7749
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  91%|█████████ | 91/100 [43:06<04:52, 32.45s/iteration]Parameters: C=100, max_iter=1000, solver=liblinear, tol=0.001, class_weight=None - Accuracy: 0.7749
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:1223: UserWarning: 'n_jobs' > 1 does not have any effect when 'solver' is set to 'liblinear'. Got 'n_jobs' = 2.
#   warnings.warn(
# Searching for best parameters:  92%|█████████▏| 92/100 [43:21<03:36, 27.12s/iteration]Parameters: C=100, max_iter=1000, solver=liblinear, tol=0.001, class_weight=balanced - Accuracy: 0.7749
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Searching for best parameters:  93%|█████████▎| 93/100 [46:03<07:53, 67.66s/iteration]Parameters: C=100, max_iter=1000, solver=sag, tol=0.0001, class_weight=None - Accuracy: 0.7749
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Searching for best parameters:  94%|█████████▍| 94/100 [48:44<09:34, 95.70s/iteration]Parameters: C=100, max_iter=1000, solver=sag, tol=0.0001, class_weight=balanced - Accuracy: 0.7749
# Searching for best parameters:  95%|█████████▌| 95/100 [49:28<06:40, 80.18s/iteration]Parameters: C=100, max_iter=1000, solver=sag, tol=0.001, class_weight=None - Accuracy: 0.7751
# Searching for best parameters:  96%|█████████▌| 96/100 [50:12<04:37, 69.43s/iteration]Parameters: C=100, max_iter=1000, solver=sag, tol=0.001, class_weight=balanced - Accuracy: 0.7751
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Searching for best parameters:  97%|█████████▋| 97/100 [53:00<04:56, 98.86s/iteration]Parameters: C=100, max_iter=1000, solver=saga, tol=0.0001, class_weight=None - Accuracy: 0.7749
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# Searching for best parameters:  98%|█████████▊| 98/100 [55:44<03:56, 118.43s/iteration]Parameters: C=100, max_iter=1000, solver=saga, tol=0.0001, class_weight=balanced - Accuracy: 0.7749
# Searching for best parameters:  99%|█████████▉| 99/100 [56:38<01:39, 99.11s/iteration] Parameters: C=100, max_iter=1000, solver=saga, tol=0.001, class_weight=None - Accuracy: 0.7752
# Searching for best parameters: 100%|██████████| 100/100 [57:46<00:00, 34.66s/iteration]Parameters: C=100, max_iter=1000, solver=saga, tol=0.001, class_weight=balanced - Accuracy: 0.7753
#
#
# ...

# %% [raw]
# Best Parameters: {'C': 0.1, 'max_iter': 1000, 'solver': 'sag', 'tol': 0.0001, 'class_weight': 'balanced'}
# Best Accuracy: 0.7759

# %% [markdown]
# # Logistic Regression + CountVectorization model with best parameters

# %%
LRmodel = LogisticRegression(C=0.1, max_iter=1000, solver='sag', tol=0.0001, class_weight='balanced', n_jobs=-1)
LRmodel.fit(X_train_counts, y_train) # Train the model on the training data
# Out:
# LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000, n_jobs=-1,
#                    solver='sag')

# %%
model_Evaluate(LRmodel)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.76      0.77    159815
#            1       0.77      0.80      0.79    160185
#
#     accuracy                           0.78    320000
#    macro avg       0.78      0.78      0.78    320000
# weighted avg       0.78      0.78      0.78    320000
#
# Accuracy: 0.779878125
